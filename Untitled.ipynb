# %% [markdown]
# ## <span style="color: #154c79;"> Before You Start  </span>

# %% [markdown]
# ### We assume that you have already installed Python on your system and are familiar with the basics of Python programming.

# %% [markdown]
# # <span style="color: #154c79;">Introduction to Image Processing </span>

# %% [markdown]
# Image processing is a field of computer science that focuses on the analysis, manipulation, and transformation of visual data—primarily images and videos. It plays a crucial role in numerous applications, from enhancing photos in social media to advanced medical imaging techniques, object detection in autonomous vehicles, and face recognition systems. Image processing techniques involve converting an image into a digital format, applying mathematical algorithms to extract valuable information, improve visual quality, or identify patterns within the data. These techniques range from basic operations, like resizing, filtering, and color adjustments, to complex tasks, such as edge detection, image segmentation, and object recognition. With the rapid advancements in machine learning and artificial intelligence, image processing has become an essential tool for automating visual tasks, providing deeper insights into visual data, and transforming the way we interact with digital images in everyday life.

# %% [markdown]
# ## <span style="color: #154c79;">  Importing Necessary Libraries </span>
#
# #### 1. OpenCV (`cv2`)
# - **Description**: OpenCV (Open Source Computer Vision Library) is the main library used for computer vision tasks. It offers a wide range of functions for image and video processing, including reading and writing images, applying filters, detecting objects, and more.
# - **Usage**: It is essential for performing all image processing and computer vision tasks, such as loading images, manipulating pixels, and implementing algorithms.
#
# #### 2. NumPy (`np`)
# - **Description**: NumPy is a fundamental package for numerical computing in Python. It supports multi-dimensional arrays and matrices, along with a vast collection of mathematical functions to operate on these arrays.
# - **Usage**: Used alongside OpenCV for efficient manipulation of images as arrays. For instance, it allows reshaping, masking, or filtering images directly, as images in OpenCV are treated as NumPy arrays.
#
# #### 3. Matplotlib (`plt`)
# - **Description**: Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. It is particularly well-suited for displaying images and plots in a clear, readable format.
# - **Usage**: Often used to display images within Jupyter Notebooks or other interactive environments, providing better control over image visualization compared to OpenCV’s built-in `cv2.imshow()`, especially when dealing with RGB formats.
#
# These libraries form the foundation for the image processing and visualization tasks we will perform, making them essential imports for any image processing project.

# %% [markdown]
# ### Now Let's Import Necessary Libraries

# %%
import cv2  # OpenCV library for computer vision tasks
import numpy as np  # NumPy for numerical operations on image arrays
import matplotlib.pyplot as plt  # Matplotlib for displaying images and plots

# %% [markdown]
# # Reading Image

# %%
image = cv2.imread('Assets/computer-vision-and-image-processing.jpg')

# Check if the image was loaded
if image is None:
    print("Error: Could not load image. Check the file path or format.")
else:
    print("Image loaded successfully!")
# Out:
# Image loaded successfully!

# %% [markdown]
# ## Reading Images with Different Options
# When reading images with OpenCV, you have several options for how the image is loaded, depending on what you need for your task. The `cv2.imread()` function allows you to specify different flags to control the color and format of the loaded image. Here’s a breakdown of these options and what they mean:

# %% [markdown]
# ### Image Reading Options with OpenCV
#
# When using OpenCV to read images, you can specify different flags to control how the image is loaded. These flags can be specified explicitly, or you can use shorthand integer values: `-1`, `0`, and `1`.
#
# #### **Standard Flags**
#
# - **`cv2.IMREAD_COLOR` (`1`)**: For full-color images (BGR format). This is useful for most image processing tasks where color information is needed.
#
# - **`cv2.IMREAD_GRAYSCALE` (`0`)**: For grayscale images. This option reduces complexity and processing by loading the image in a single channel, which is helpful when color is not necessary.
#
# - **`cv2.IMREAD_UNCHANGED` (`-1`)**: For images that include an alpha channel or other extra channels. This option preserves the original number of channels in the image, loading it exactly as it is.
#
# - **`cv2.IMREAD_REDUCED_COLOR_*`**: For large images where reduced resolution is acceptable. This flag reduces the image size by a factor of 2, 4, or 8, which can save memory and processing time.
#
# - **`cv2.IMREAD_REDUCED_GRAYSCALE_*`**: For large grayscale images with reduced resolution. This flag reduces the grayscale image size by a factor of 2, 4, or 8.
#
# #### **Using Shorthand Integer Values**
#
# - **`1`**: Equivalent to `cv2.IMREAD_COLOR`, reads the image in full color.
# - **`0`**: Equivalent to `cv2.IMREAD_GRAYSCALE`, reads the image in grayscale.
# - **`-1`**: Equivalent to `cv2.IMREAD_UNCHANGED`, reads the image with all channels, including alpha if present.
#
# By choosing the appropriate flag or shorthand value, you can control how OpenCV reads and processes your images to fit your specific needs, balancing factors like color, complexity, and memory usage.

# %% [markdown]
# Example of different options

# %%
bird_image = cv2.imread('Assets/most-colorful-birds-on-the-planet.jpg', 1)

# cv2.imshow('colorful bird',bird_image)
# cv2.waitKey(0)  # Wait for a key press to close the window
# cv2.destroyAllWindows() 

plt.imshow(bird_image)

# %% [markdown]
# Display Images with Matplotlib Instead of `cv2.imshow()`
#
# Since Jupyter Notebook is designed for interactive plotting, using Matplotlib to display images is often a better approach.

# %% [markdown]
# ### In Google Colab

# %%
from google.colab.patches import cv2_imshow

cv2_imshow(bird_image)

# %% [markdown]
# ### Displaying Images with OpenCV
#
# - **Method**: `cv2.imshow()`
# - **Description**: OpenCV provides the `cv2.imshow()` function to display images in a separate window. This method is well-suited for real-time image processing tasks where interactive display is required.
#
#     **Pros**:
#     - **Efficiency**: Suitable for high-performance applications and real-time processing.
#
#     - **Integration**: Directly integrates with OpenCV’s image processing functions.
#
#     **Cons**:
#     - **Environment**: May not work as smoothly in environments like Jupyter Notebooks or remote servers where GUI-based windows are not available.
#
# ### Displaying Images with Matplotlib
#
# - **Method**: `plt.imshow()`
#
# - **Description**: Matplotlib is often used for displaying images within Jupyter Notebooks or other interactive environments. It provides extensive control over visualization, including axis labels, titles, and other plot customizations.
#
#     **Pros**:
#     - **Customization**: Provides rich options for customizing the plot and visualizations.
#
#     - **Interactive Notebooks**: Ideal for displaying images within Jupyter Notebooks or other interactive environments.
#
#     **Cons**:
#     - **Performance**: May not be as efficient as OpenCV for real-time applications or large-scale image processing.

# %% [markdown]
# ### Checking the Size of an Image
#
# To determine the size (dimensions) of an image in OpenCV, you can use the `shape` attribute of the image array. This provides information about the image’s height, width, and the number of color channels.
#
# #### How to Check the Size of an Image

# %%
# Get the dimensions of the image
dimensions = image.shape

# Extract height, width, and number of channels
height, width, channels = dimensions

# Display the size information
print(f"Width: {width} pixels")
print(f"Height: {height} pixels")
print(f"Number of Channels: {channels}")
# Out:
# Width: 1820 pixels
# Height: 1024 pixels
# Number of Channels: 3

# %% [markdown]
# * Understanding the number of channels can help you decide if you need to convert an image from color to grayscale or vice versa.
#
# * Use image.shape to quickly access the dimensions and channels of an image.
#
# * Understanding image size is crucial for proper image processing and manipulation in computer vision tasks.

# %%
blue_channel = image[:, :, 0]
green_channel = image[:, :, 1]
red_channel = image[:, :, 2]

# %%
# Each channels
# create figure 
fig = plt.figure(figsize=(10, 7)) 
  
# setting values to rows and column variables 
rows = 1
columns = 3
  
# Adds a subplot at the 1st position 
fig.add_subplot(rows, columns, 1) 
  
# showing image 
plt.imshow(blue_channel) 
plt.axis('off') 
plt.title("Blue channel") 
  
# Adds a subplot at the 2nd position 
fig.add_subplot(rows, columns, 2) 
  
# showing image 
plt.imshow(green_channel) 
plt.axis('off') 
plt.title("Green channel") 
  
# Adds a subplot at the 3rd position 
fig.add_subplot(rows, columns, 3) 
  
# showing image 
plt.imshow(red_channel) 
plt.axis('off') 
plt.title("Red channel")

# %% [markdown]
# ### Converting the Image from BGR to RGB
#
# When working with images in OpenCV, it’s important to understand the color format being used. By default, OpenCV reads images in BGR (Blue, Green, Red) format, whereas most other libraries, like Matplotlib, use the RGB (Red, Green, Blue) format. This discrepancy can cause images to appear with incorrect colors when displayed outside OpenCV.
#
# #### **Why Convert BGR to RGB?**
#
# 1. **Consistency with Other Libraries**: Many image processing and visualization libraries, such as Matplotlib, PIL, and TensorFlow, use the RGB format. Converting images from BGR to RGB ensures consistent color representation across different tools.
#
# 2. **Accurate Color Display**: Without conversion, images displayed using Matplotlib or other non-OpenCV libraries will have swapped color channels, leading to incorrect color representation (e.g., blues appearing as reds).
#
# 3. **Standardization**: RGB is a widely accepted standard in digital imaging, making it easier to share, manipulate, and process images correctly when working with different software and algorithms.
#
# #### **How to Convert BGR to RGB in OpenCV**
#
# To convert an image from BGR to RGB, you can use the `cv2.cvtColor()` function with the appropriate flag:

# %%
plt.imshow(image)

# Convert BGR to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image using Matplotlib
plt.imshow(image_rgb)
plt.title('Image in RGB Format')
# plt.axis('on')
# plt.colorbar()
plt.show()

# %% [markdown]
#  # Displaying an Image with Matplotlib

# %% [markdown]
# ### Displaying Images with OpenCV and Matplotlib
#
# When it comes to displaying images, OpenCV and Matplotlib offer different methods and options. Here’s a comparison of these two approaches:
#
# #### **1. Displaying Images with OpenCV**
#
# - **Method**: `cv2.imshow()`
# - **Description**: OpenCV provides the `cv2.imshow()` function to display images in a separate window. This method is well-suited for real-time image processing tasks where interactive display is required.
#
# To control the size of the window when displaying an image with OpenCV, you need to resize the window before displaying the image. OpenCV does not have a direct function to set the window size during cv2.imshow(). Instead, you can use cv2.namedWindow() with the cv2.WINDOW_NORMAL flag to make the window resizable, and then use cv2.resizeWindow() to set the desired size.
#
# - **Usage**:

# %%
# # Create a named window that can be resized
# cv2.namedWindow('Image Title', cv2.WINDOW_NORMAL)

# # Set the desired window size (width, height)
# cv2.resizeWindow('Image Title', 800, 600)  # Adjust the size as needed

# # Display the image
# cv2.imshow('Image Title', image)
# cv2.waitKey(0)  # Wait for a key press to close the window
# cv2.destroyAllWindows()  # Close all OpenCV windows

# %% [markdown]
# ### Understanding `cv2.waitKey()`
#
# The `cv2.waitKey()` function in OpenCV is used to capture keyboard events and control the flow of a program when displaying images or videos. It plays a crucial role in managing how long an image or video frame is displayed.
#
# #### **Function Overview**
# - **Function**: `cv2.waitKey([delay])`
# - **Purpose**: Waits for a specific amount of time for a key press. It is essential when displaying images or videos using OpenCV, allowing you to pause the execution and interact with the window.
#
# #### **Parameters**
# - **`delay`**: An integer value specifying the wait time in milliseconds. If set to `0`, it waits indefinitely until a key is pressed. Examples include:
#   - **`cv2.waitKey(0)`**: Waits indefinitely for a key press. Commonly used for displaying images, allowing the user to view the image until they close it by pressing a key.
#   - **`cv2.waitKey(1)`**: Waits for 1 millisecond for a key press, often used in video processing loops to keep the display window updated with new frames.
#   - **`cv2.waitKey(30)`**: Waits for 30 milliseconds, creating a frame rate of about 33 frames per second (fps) in video playback.
#
# #### **Return Value**
# - **Return**: `cv2.waitKey()` returns the ASCII code of the key pressed. If no key is pressed within the specified delay, it returns `-1`. This return value can be used to handle specific key events in your program.

# %% [markdown]
# ### Resizing and Rotating Images with OpenCV
#
# Resizing and rotating are common image processing tasks that can be easily accomplished using OpenCV. Below are detailed explanations and code examples for resizing and rotating an image.
#
# ### 1. Resizing an Image
#
# To resize an image, use the `cv2.resize()` function, which allows you to specify the new dimensions or scale factors.

# %%
resized_image = cv2.resize(image, (800, 600))  # Resize to 800x600 pixels

# Alternatively, resize by scaling factors
# resized_image = cv2.resize(image, None, fx=0.5, fy=0.5)  # Half the original size

# Display the resized image using Matplotlib
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB
plt.title('Resized Image')
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# ### Explanation of Resizing
#
# - **`cv2.resize(image, (width, height))`**: Resizes the image to the specified width and height. This function allows you to set exact dimensions for the output image.
#
# - **`cv2.cvtColor(image, cv2.COLOR_BGR2RGB)`**: Converts the image from BGR format (used by OpenCV) to RGB format (used by Matplotlib). This conversion is necessary because Matplotlib displays images in RGB format, while OpenCV uses BGR format by default.
#
# - **Scaling Factors**: You can resize an image by specifying scaling factors (`fx` and `fy`). These factors adjust the size of the image relative to its original dimensions. For example:
#   - **`fx=0.5` and `fy=0.5`**: Resize the image to half of its original width and height.
#   - **`fx=2.0` and `fy=2.0`**: Resize the image to twice its original width and height.
#
# ### Summary
# - **Resize**: Use `cv2.resize()` to specify exact dimensions.
# - **Convert**: Use `cv2.cvtColor()` to convert BGR to RGB for correct display with Matplotlib.
# - **Scaling**: Adjust image size using scaling factors to resize relative to original dimensions.

# %% [markdown]
# ### 2. Rotating an Image
#
# To rotate an image, use `cv2.getRotationMatrix2D()` to create a rotation matrix and `cv2.warpAffine()` to apply the transformation. Display the result using Matplotlib.

# %%
# Get the dimensions of the image
(h, w) = image.shape[:2]

# Define the center of the image
center = (w // 2, h // 2)

# Define the rotation angle in degrees (positive for counterclockwise)
angle = 45

# Define the scale factor (1.0 means original size)
scale = 1.0

# Create the rotation matrix
rotation_matrix = cv2.getRotationMatrix2D(center, angle, scale)

# Rotate the image using the rotation matrix
rotated_image = cv2.warpAffine(image, rotation_matrix, (w, h))

# Display the rotated image using Matplotlib
plt.imshow(cv2.cvtColor(rotated_image, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB
plt.title('Rotated Image')
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# ### Explanation of Rotation
#
# - **`cv2.getRotationMatrix2D(center, angle, scale)`**: Creates a 2D rotation matrix specifying the center of rotation, the rotation angle (in degrees), and the scale factor. This matrix defines how the image will be rotated.
#
# - **`cv2.warpAffine(image, rotation_matrix, (width, height))`**: Applies the rotation matrix to the image, transforming it according to the specified dimensions. This function performs the actual rotation of the image based on the matrix created.
#
# ### Summary
#
# - **Rotation Matrix**: Use `cv2.getRotationMatrix2D()` to create a matrix that defines the rotation.
# - **Apply Rotation**: Use `cv2.warpAffine()` to rotate the image based on the rotation matrix.
# - **Display**: Convert the image to RGB format for correct display in Matplotlib.

# %% [markdown]
# ### Cropping images

# %% [markdown]
# ### Saving image

# %%
cv2.imwrite('rotated_image.jpg', rotated_image)
# Out:
# True

# %%
# Open the default camera
cap = cv2.VideoCapture(0)

# Check if the camera opened successfully
if not cap.isOpened():
    print("Error: Could not open the camera.")
    cap.release()  # Release the camera
    cv2.destroyAllWindows()
    exit()

try:
    # Continuously capture frames from the camera
    while True:
        # Read a frame from the camera
        ret, frame = cap.read()
        
        # Check if the frame was captured successfully
        if not ret:
            print("Error: Failed to capture frame.")
            break
        
        # Display the captured frame
        cv2.imshow('Camera Feed', frame)
        
        # Wait for 1 ms and check if the 'q' key was pressed to exit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

except KeyboardInterrupt:
    print("Video feed stopped manually.")

finally:
    # Release the camera and close all OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

# %%
# Open the default camera
cap = cv2.VideoCapture(0)

# Check if the camera opened successfully
if not cap.isOpened():
    print("Error: Could not open the camera.")
    cap.release()
    cv2.destroyAllWindows()
    exit()

try:
    # Continuously capture frames from the camera
    while True:
        # Read a frame from the camera
        ret, frame = cap.read()
        
        # Check if the frame was captured successfully
        if not ret:
            print("Error: Failed to capture frame.")
            break
        
        # Get frame dimensions
        height, width = frame.shape[:2]
        
        # Draw a line on the frame
        # Syntax: cv2.line(image, start_point, end_point, color, thickness)
        start_point = (163, 50)
        end_point = (width , height - 250)
        cv2.line(frame, start_point, end_point, (0, 255, 0), 5)  # Green line
        
        # Draw a circle on the frame
        # Syntax: cv2.circle(image, center, radius, color, thickness)
        center = (width // 2, height // 2)
        radius = 50
        cv2.circle(frame, center, radius, (255, 0, 0), 3)  # Blue circle
        
        # Display the modified frame
        cv2.imshow('Live Video with Shapes', frame)
        
        # Wait for 1 ms and check if the 'q' key was pressed to exit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

except KeyboardInterrupt:
    print("Video feed stopped manually.")

finally:
    # Release the camera and close all OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ### Extra materials

# %% [markdown]
# ### REVIEW ASSIGNMENT
